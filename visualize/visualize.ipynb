# %%
import pandas as pd
import sys  
import os
import numpy as np

# %%
#get current working directory
cwd = os.getcwd()
#move to the directory where the script is located
script_dir = os.path.dirname(os.path.abspath(cwd))
os.chdir(script_dir)
#move to t

# %%
# %pwd
# Out:
# 'c:\\Users\\peera\\Desktop\\DroughtLSTM_oneday'

# %%
# %cd ./visualize
# Out:
# c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

full_df  = pd.read_csv('../data/full_newtime.csv')
# Assuming 'spei_multi' contains the necessary data
first_timestamp = full_df['time'].iloc[0]
data_to_plot = full_df[full_df['time'] == first_timestamp]

plt.figure(figsize=(10, 10))
plt.scatter(data_to_plot['lon'], data_to_plot['lat'], c=data_to_plot['spei'], cmap='viridis', s=50)
plt.colorbar(label='SPEI Value')
plt.title(f'Spatial Plot at {first_timestamp}')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
for i in range (0,5):
    unique_times = full_df['time'].drop_duplicates().sort_values().reset_index(drop=True)
    first_timestamp = unique_times.iloc[i]  # 10th time step (0-based index)

    full_df  = pd.read_csv('../data/full_newtime.csv')
    print(f"First timestamp for plotting: {first_timestamp}")
    data_to_plot = full_df[full_df['time'] == first_timestamp]

    plt.figure(figsize=(8, 10))
    plt.scatter(data_to_plot['lon'], data_to_plot['lat'], c=data_to_plot['spei'], cmap='viridis', s=50)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid()
    
    #save
    plt.savefig(f'spatial_plot_{first_timestamp}_nobar.png')
    plt.show()
# Out:
# First timestamp for plotting: 1901-01-16
# First timestamp for plotting: 1901-02-15
# First timestamp for plotting: 1901-03-16
# First timestamp for plotting: 1901-04-16
# First timestamp for plotting: 1901-05-16

# %%
full_df.head()
# Out:
#       lon   lat        time        tmp  dtr   cld        tmx        tmn  \
# 0  101.25  6.25  1901-01-16  25.300001  9.3  62.5  30.000000  20.700000
# 1  101.75  6.25  1901-01-16  25.800001  8.0  65.1  29.800001  21.800001
# 2   99.75  6.75  1901-01-16  27.800001  9.8  55.0  32.700000  22.900000
# 3  100.25  6.75  1901-01-16  26.900000  9.8  58.8  31.800001  22.000000
# 4  100.75  6.75  1901-01-16  26.100000  9.0  62.5  30.600000  21.600000
#
#           pre    wet        vap      spei   soi   dmi       pdo  nino4  \
# 0   84.600000  10.28  25.200000 -0.384595 -0.09 -0.54  1.114457   0.59
# 1  131.500000  13.08  26.700000 -0.324920 -0.09 -0.54  1.114457   0.59
# 2   37.400000   4.00  26.000000 -0.612856 -0.09 -0.54  1.114457   0.59
# 3   37.800000   5.36  25.800001 -0.581451 -0.09 -0.54  1.114457   0.59
# 4   52.100002   7.28  26.100000 -0.330006 -0.09 -0.54  1.114457   0.59
#
#    nino34  nino3         pet
# 0    0.82   0.46  108.500000
# 1    0.82   0.46  102.300000
# 2    0.82   0.46  133.300000
# 3    0.82   0.46  124.000000
# 4    0.82   0.46  111.600003

# %%
lat_value = 6.25  # Replace with your specific latitude
lon_value = 101.25  # Replace with your specific longitude
train_end_date = '2017-12-31'  # Replace with your train end date
val_end_date = '2020-12-31'  # Replace with your validation end date

# Filter the data for the specific lat, lon
temporal_data = full_df[(full_df['lat'] == lat_value) & (full_df['lon'] == lon_value)]

import pandas as pd
import matplotlib.pyplot as plt

# Ensure time is datetime
temporal_data['time'] = pd.to_datetime(temporal_data['time'])

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(temporal_data['time'], temporal_data['spei'], label='SPEI Predicted', color='blue')

# Add vertical lines
plt.axvline(pd.to_datetime(train_end_date), color='orange', linestyle='--', label='Train End Date')
plt.axvline(pd.to_datetime(val_end_date), color='green', linestyle='--', label='Validation End Date')

plt.title(f'Temporal Plot for Lat: {lat_value}, Lon: {lon_value}')
plt.xlabel('Time')
plt.ylabel('SPEI Predicted')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\peera\AppData\Local\Temp\ipykernel_50144\3222752975.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_data['time'] = pd.to_datetime(temporal_data['time'])

# %%
# Spatial Scatter Plot
first_timestamp = full_df['time'].iloc[0]
data_to_plot = full_df[full_df['time'] == first_timestamp]

plt.figure(figsize=(10, 10))
plt.scatter(data_to_plot['lon'], data_to_plot['lat'], c=data_to_plot['spei'], cmap='jet', s=50)
plt.colorbar(label='SPEI Value')
plt.title(f'Spatial Plot at {first_timestamp}')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()
plt.show()

# Temporal Line Plot for a specific location
lat_value = 6.25  # Replace with your specific latitude
lon_value = 101.25  # Replace with your specific longitude
temporal_data = full_df[(full_df['lat'] == lat_value) & (full_df['lon'] == lon_value)]

# Ensure time is datetime
temporal_data['time'] = pd.to_datetime(temporal_data['time'])

plt.figure(figsize=(12, 6))
plt.plot(temporal_data['time'], temporal_data['spei'], label='SPEI', color='blue')
plt.title(f'Temporal Plot for Lat: {lat_value}, Lon: {lon_value}')
plt.xlabel('Time')
plt.ylabel('SPEI')
plt.legend()
plt.grid()
plt.show()

# Heatmap of SPEI values over time
pivot_table = full_df.pivot_table(values='spei', index='lat', columns='time', aggfunc='mean')
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, cmap='plasma', cbar_kws={'label': 'SPEI Value'})
plt.title('Heatmap of SPEI Values Over Time')
plt.xlabel('Time')
plt.ylabel('Latitude')
plt.show()
# Out:
# C:\Users\peera\AppData\Local\Temp\ipykernel_50144\379699081.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_data['time'] = pd.to_datetime(temporal_data['time'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

# --- Settings ---
lat_value = 6.25
lon_value = 101.25
train_end_date = '2017-12-31'
val_end_date = '2020-12-31'
rolling_window = 12  # months

# --- Data prep ---
temporal_data = full_df[(full_df['lat'] == lat_value) & (full_df['lon'] == lon_value)].copy()
temporal_data['time'] = pd.to_datetime(temporal_data['time'])
temporal_data = temporal_data.sort_values('time')  # ensure time is sorted
temporal_data['rolling_mean'] = temporal_data['spei'].rolling(window=rolling_window, center=True).mean()

# Global mean SPEI (optional smoothing)
full_df['time'] = pd.to_datetime(full_df['time'])
global_mean = full_df.groupby('time')['spei'].mean()

# --- Plot ---
plt.figure(figsize=(14, 6))
plt.plot(temporal_data['time'], temporal_data['spei'], label=f'SPEI at {lat_value}_{lon_value}', color='blue', linewidth=0.7, alpha=0.8)
plt.plot(temporal_data['time'], temporal_data['rolling_mean'], label=f'{rolling_window}-month Rolling Mean', color='green', linewidth=2)
plt.plot(global_mean.index, global_mean.values, label='Global Mean SPEI', color='red', linestyle='--', linewidth=0.5, alpha=0.6)

# Vertical lines
plt.axvline(pd.to_datetime(train_end_date), color='orange', linestyle='--', label='Train End Date')
plt.axvline(pd.to_datetime(val_end_date), color='darkgreen', linestyle='--', label='Validation End Date')

# Horizontal mean line at this location
mean_spei = temporal_data['spei'].mean()
plt.axhline(mean_spei, color='gray', linestyle='--', linewidth=1, label=f'Mean SPEI = {mean_spei:.2f}')

# --- Aesthetics ---
plt.title(f'SPEI at ({lat_value}, {lon_value}) vs Global Mean')
plt.xlabel('Time')
plt.ylabel('SPEI')
plt.legend(loc='lower left', fontsize=8)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.hist(full_df['spei'].dropna(), bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of SPEI Values')
plt.xlabel('SPEI')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
full_df['time'] = pd.to_datetime(full_df['time'], errors='coerce')

full_df['year'] = full_df['time'].dt.year

plt.figure(figsize=(14, 5))
sns.boxplot(data=full_df, x='year', y='spei')
plt.title('Yearly Boxplot of SPEI')
plt.xlabel('Year')
plt.ylabel('SPEI')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_features = full_df.drop(columns=['time', 'lat', 'lon',"year"])

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df_features)
plt.title('Boxplot of All Features')
plt.xlabel('Features')
plt.ylabel('Values')
plt.yscale('symlog')  # Set y-axis to logarithmic scale
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
location_stats = full_df.groupby(['lat', 'lon'])['spei'].agg(['mean', 'std', 'min', 'max']).reset_index()
print(location_stats.head())
# Out:
#     lat     lon      mean       std       min       max
# 0  6.25  101.25  0.003206  0.994840 -2.996007  2.865483
# 1  6.25  101.75  0.002399  0.997513 -3.212831  2.885987
# 2  6.75   99.75  0.002607  0.994912 -3.073571  2.765210
# 3  6.75  100.25  0.003211  0.992250 -2.547545  2.828386
# 4  6.75  100.75  0.001536  0.993348 -2.319993  2.859126

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 4
#       1 import seaborn as sns
#       3 # Pair plot to visualize relationships between features
# ----> 4 sns.pairplot(full_df)
#       5 plt.title('Pair Plot of Full DataFrame Features')
#       6 plt.show()
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\axisgrid.py:2163, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2161 if kind == "scatter":
#    2162     from .relational import scatterplot  # Avoid circular import
# -> 2163     plotter(scatterplot, **plot_kws)
#    2164 elif kind == "reg":
#    2165     from .regression import regplot  # Avoid circular import
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\axisgrid.py:1425, in PairGrid.map_offdiag(self, func, **kwargs)
#    1414 """Plot with a bivariate function on the off-diagonal subplots.
#    1415
#    1416 Parameters
#    (...)
#    1422
#    1423 """
#    1424 if self.square_grid:
# -> 1425     self.map_lower(func, **kwargs)
#    1426     if not self._corner:
#    1427         self.map_upper(func, **kwargs)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\axisgrid.py:1395, in PairGrid.map_lower(self, func, **kwargs)
#    1384 """Plot with a bivariate function on the lower diagonal subplots.
#    1385
#    1386 Parameters
#    (...)
#    1392
#    1393 """
#    1394 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1395 self._map_bivariate(func, indices, **kwargs)
#    1396 return self
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\axisgrid.py:1574, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1572     if ax is None:  # i.e. we are in corner mode
#    1573         continue
# -> 1574     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1575 self._add_axis_labels()
#    1577 if "hue" in signature(func).parameters:
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\axisgrid.py:1615, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1611 if "hue" not in kwargs:
#    1612     kwargs.update({
#    1613         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1614     })
# -> 1615 func(x=x, y=y, **kwargs)
#    1617 self._update_legend_data(ax)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\relational.py:404, in _ScatterPlotter.plot(self, ax, kws)
#     400 def plot(self, ax, kws):
#     401
#     402     # --- Determine the visual attributes of the plot
# --> 404     data = self.comp_data.dropna()
#     405     if data.empty:
#     406         return
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\seaborn\_base.py:994, in VectorPlotter.comp_data(self)
#     992 for converter, orig in grouped:
#     993     orig = orig.mask(orig.isin([np.inf, -np.inf]), np.nan)
# --> 994     orig = orig.dropna()
#     995     if var in self.var_levels:
#     996         # TODO this should happen in some centralized location
#     997         # it is similar to GH2419, but more complicated because
#     998         # supporting `order` in categorical plots is tricky
#     999         orig = orig[orig.isin(self.var_levels[var])]
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pandas\core\series.py:5900, in Series.dropna(self, axis, inplace, how, ignore_index)
#    5897 self._get_axis_number(axis or 0)
#    5899 if self._can_hold_na:
# -> 5900     result = remove_na_arraylike(self)
#    5901 else:
#    5902     if not inplace:
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pandas\core\dtypes\missing.py:725, in remove_na_arraylike(arr)
#     723     return arr[notna(arr)]
#     724 else:
# --> 725     return arr[notna(np.asarray(arr))]
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pandas\core\series.py:1151, in Series.__getitem__(self, key)
#    1149     key = check_bool_indexer(self.index, key)
#    1150     key = np.asarray(key, dtype=bool)
# -> 1151     return self._get_rows_with_mask(key)
#    1153 return self._get_with(key)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pandas\core\series.py:1217, in Series._get_rows_with_mask(self, indexer)
#    1216 def _get_rows_with_mask(self, indexer: npt.NDArray[np.bool_]) -> Series:
# -> 1217     new_mgr = self._mgr.get_rows_with_mask(indexer)
#    1218     return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(self)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pandas\core\internals\managers.py:1968, in SingleBlockManager.get_rows_with_mask(self, indexer)
#    1964 else:
#    1965     # TODO(CoW) in theory only need to track reference if new_array is a view
#    1966     refs = blk.refs
# -> 1968 bp = BlockPlacement(slice(0, len(array)))
#    1969 block = type(blk)(array, placement=bp, ndim=1, refs=refs)
#    1971 new_idx = self.index[indexer]
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation Metrics data

# %%
import os
import json
import pandas as pd
from glob import glob

import os
import json
import pandas as pd
from glob import glob

def load_all_metrics_json(root_dir):
    all_metrics = []
    json_files = glob(os.path.join(root_dir, '**', '*metrics*.json'), recursive=True)

    for json_file in json_files:
        if not os.path.isfile(json_file):
            print(f"⚠️ Skipping non-file: {json_file}")
            continue
        print(f"📄 Loading {json_file}")
        try:
            with open(json_file, 'r') as f:
                data = json.load(f)

            if not isinstance(data, dict):
                print(f"⚠️ Skipping non-dict JSON: {json_file}")
                continue

            flattened = {}
            for split, metrics in data.items():
                if not isinstance(metrics, dict):
                    print(f"⚠️ Skipping invalid split '{split}' in {json_file}")
                    continue
                for metric_name, value in metrics.items():
                    flattened[f"{split}_{metric_name}"] = value

            # Use folder name as a unique identifier
            folder_name = os.path.basename(os.path.dirname(json_file))
            flattened['folder_name'] = folder_name  # Optional if using index instead
            flattened['source_path'] = json_file

            all_metrics.append(flattened)

        except Exception as e:
            print(f"❌ Failed to load {json_file}: {e}")

    df = pd.DataFrame(all_metrics)

    return df

# Example usage
root_dir = os.path.join(os.getcwd(),"..",  "run_outputs")
df_metrics = load_all_metrics_json(root_dir)
print(df_metrics.head())
# Out:
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\cnn2dlstm_PET\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\cnn2dlstm_PRE\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\cnn2dlstm_SPEI\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\cnn2dlstm_test\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\CNN3D_test_PET\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\CNN3D_test_PRE\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\CNN3D_test_Run\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\CNN3D_test_SPEI\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PET_Forecasting_Global_XGBoost\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PET_SARIMA_Local_Run_sarima_local\all_sarima_local_models_evaluation_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PET_SARIMA_Local_Run_sarima_local\all_sarima_local_models_evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PET_XGB_Local_Run_local\all_local_models_evaluation_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PET_XGB_Local_Run_local\all_local_models_evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_ConvLSTM_EncoderDecoder_Run\global_convlstm_improved_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_Forecasting_Global_XGBoost\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_LSTM_Global_Run\global_lstm_model_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_SARIMA_Local_Run_sarima_local\all_sarima_local_models_evaluation_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_SARIMA_Local_Run_sarima_local\all_sarima_local_models_evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_XGB_Local_Run_local\all_local_models_evaluation_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\PRE_XGB_Local_Run_local\all_local_models_evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_CNN1D_Global_Run\global_cnn1d_model_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_CNN3D_Global_Run\global_cnn3d_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_Forecasting_Global_XGBoost\evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_LSTM_Global_Run\global_lstm_model_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_LSTM_Local_Run\all_lstm_local_models_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_LSTM_Local_Run\all_lstm_local_models_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_SARIMA_Local_Run_sarima_local\all_sarima_local_models_evaluation_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_SARIMA_Local_Run_sarima_local\all_sarima_local_models_evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_XGB_Local_Run_local\all_local_models_evaluation_metrics.json
# ⚠️ Skipping non-dict JSON: c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\SPEI_XGB_Local_Run_local\all_local_models_evaluation_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\test_CNN3D_Global_Run\global_cnn3d_metrics.json
# 📄 Loading c:\Users\peera\Desktop\DroughtLSTM_oneday\visualize\..\run_outputs\test_Forecasting_Global_XGBoost\evaluation_metrics.json
#    train_rmse  train_mae  train_r2   val_rmse    val_mae    val_r2  \
# 0   16.283096  11.711056  0.349852  17.991436  13.153562  0.245756
# 1   83.277412  56.462780  0.623000  96.823723  70.338356  0.464067
# 2    0.997732   0.812314 -0.003963   1.043339   0.891402 -0.252149
# 3   64.316452  43.024647  0.775130  63.825657  44.809402  0.767117
# 4    4.696808   3.058579  0.871606   5.904472   3.929081  0.851887
#
#     test_rmse   test_mae   test_r2     folder_name  \
# 0   15.352223  11.381064  0.267059   cnn2dlstm_PET
# 1  101.788948  71.798531  0.515878   cnn2dlstm_PRE
# 2    1.107618   0.934870 -0.136553  cnn2dlstm_SPEI
# 3   72.938461  50.582729  0.751420  cnn2dlstm_test
# 4    4.763505   3.260989  0.873663  CNN3D_test_PET
#
#                                          source_path  validation_rmse  \
# 0  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 1  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 2  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 3  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 4  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
#
#    validation_mae  validation_r2  train_mse  train_mape  validation_mse  \
# 0             NaN            NaN        NaN         NaN             NaN
# 1             NaN            NaN        NaN         NaN             NaN
# 2             NaN            NaN        NaN         NaN             NaN
# 3             NaN            NaN        NaN         NaN             NaN
# 4             NaN            NaN        NaN         NaN             NaN
#
#    validation_mape  test_mse  test_mape
# 0              NaN       NaN        NaN
# 1              NaN       NaN        NaN
# 2              NaN       NaN        NaN
# 3              NaN       NaN        NaN
# 4              NaN       NaN        NaN

# %%
df_metrics
# Out:
#       train_rmse   train_mae   train_r2   val_rmse    val_mae    val_r2  \
# 0      16.283096   11.711056   0.349852  17.991436  13.153562  0.245756
# 1      83.277412   56.462780   0.623000  96.823723  70.338356  0.464067
# 2       0.997732    0.812314  -0.003963   1.043339   0.891402 -0.252149
# 3      64.316452   43.024647   0.775130  63.825657  44.809402  0.767117
# 4       4.696808    3.058579   0.871606   5.904472   3.929081  0.851887
# 5      43.441471   26.053858   0.743754  42.143089  26.702225  0.741234
# 6      44.127270   21.088480   0.735600  43.750076  23.092395  0.721123
# 7       0.645014    0.379025   0.013476   0.669590   0.409612 -0.007446
# 8       2.242872    1.703355   0.987665        NaN        NaN       NaN
# 9       0.506060    0.383949   0.398239        NaN        NaN       NaN
# 10    445.588970   13.110221   0.975742        NaN        NaN       NaN
# 11  18075.938116  104.513856   0.018472        NaN        NaN       NaN
# 12      1.499698    0.987240  -0.519163        NaN        NaN       NaN
# 13      1.046989    0.850183  -0.105783        NaN        NaN       NaN
# 14      0.564933    0.443428   0.678127        NaN        NaN       NaN
# 15      0.995630    0.813519   0.001380        NaN        NaN       NaN
# 16   6965.436035   74.394615 -16.079952        NaN        NaN       NaN
# 17      2.067983    1.585047   0.989513        NaN        NaN       NaN
#
#        test_rmse    test_mae    test_r2                      folder_name  \
# 0      15.352223   11.381064   0.267059                    cnn2dlstm_PET
# 1     101.788948   71.798531   0.515878                    cnn2dlstm_PRE
# 2       1.107618    0.934870  -0.136553                   cnn2dlstm_SPEI
# 3      72.938461   50.582729   0.751420                   cnn2dlstm_test
# 4       4.763505    3.260989   0.873663                   CNN3D_test_PET
# 5      44.679797   28.346233   0.706057                   CNN3D_test_PRE
# 6      50.558461   27.208007   0.623619                   CNN3D_test_Run
# 7       0.651818    0.395769  -0.001749                  CNN3D_test_SPEI
# 8       7.115232    5.337263   0.842564   PET_Forecasting_Global_XGBoost
# 9       0.538402    0.425542   0.504844  PRE_ConvLSTM_EncoderDecoder_Run
# 10    839.782582   17.202585   0.960761   PRE_Forecasting_Global_XGBoost
# 11  16323.513174  104.363764   0.012735              PRE_LSTM_Global_Run
# 12      1.691156    1.067154  -1.255846            SPEI_CNN1D_Global_Run
# 13      1.129393    0.936347  -0.181678            SPEI_CNN3D_Global_Run
# 14      1.063857    0.885687  -0.048518  SPEI_Forecasting_Global_XGBoost
# 15      0.878985    0.795628  -0.040174             SPEI_LSTM_Global_Run
# 16   6782.065918   73.031639 -20.090580            test_CNN3D_Global_Run
# 17      7.302454    5.595989   0.834170  test_Forecasting_Global_XGBoost
#
#                                           source_path  validation_rmse  \
# 0   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 1   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 2   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 3   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 4   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 5   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 6   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 7   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 8   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         6.183279
# 9   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         0.555342
# 10  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...       646.838748
# 11  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...     19076.156517
# 12  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         1.633447
# 13  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         1.053275
# 14  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         0.961962
# 15  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         1.031030
# 16  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      7694.236816
# 17  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         6.333017
#
#     validation_mae  validation_r2  train_mse   train_mape  validation_mse  \
# 0              NaN            NaN        NaN          NaN             NaN
# 1              NaN            NaN        NaN          NaN             NaN
# 2              NaN            NaN        NaN          NaN             NaN
# 3              NaN            NaN        NaN          NaN             NaN
# 4              NaN            NaN        NaN          NaN             NaN
# 5              NaN            NaN        NaN          NaN             NaN
# 6              NaN            NaN        NaN          NaN             NaN
# 7              NaN            NaN        NaN          NaN             NaN
# 8         4.537861       0.910912        NaN          NaN             NaN
# 9         0.449461       0.355468   0.256097  186188864.0        0.308405
# 10       13.975708       0.966447        NaN          NaN             NaN
# 11      106.985327       0.010471        NaN          NaN             NaN
# 12        1.002452      -1.065127        NaN          NaN             NaN
# 13        0.893532      -0.276111        NaN          NaN             NaN
# 14        0.830690      -0.064439        NaN          NaN             NaN
# 15        0.852902      -0.134666        NaN          NaN             NaN
# 16       79.138405     -16.928562        NaN          NaN             NaN
# 17        4.713589       0.906545        NaN          NaN             NaN
#
#     validation_mape  test_mse    test_mape
# 0               NaN       NaN          NaN
# 1               NaN       NaN          NaN
# 2               NaN       NaN          NaN
# 3               NaN       NaN          NaN
# 4               NaN       NaN          NaN
# 5               NaN       NaN          NaN
# 6               NaN       NaN          NaN
# 7               NaN       NaN          NaN
# 8               NaN       NaN          NaN
# 9        195.039078  0.289877  1235246.125
# 10              NaN       NaN          NaN
# 11              NaN       NaN          NaN
# 12              NaN       NaN          NaN
# 13              NaN       NaN          NaN
# 14              NaN       NaN          NaN
# 15              NaN       NaN          NaN
# 16              NaN       NaN          NaN
# 17              NaN       NaN          NaN

# %%
#drop PRE_PET_ConvLSTM-MultiTask row in index
if 'PRE_PET_ConvLSTM-MultiTask' in df_metrics.index:
    print("Dropping PRE_PET_ConvLSTM-MultiTask row from index")
    df_metrics = df_metrics.drop('PRE_PET_ConvLSTM-MultiTask')

# %%
df_metrics
# Out:
#       train_rmse   train_mae   train_r2   val_rmse    val_mae    val_r2  \
# 0      16.283096   11.711056   0.349852  17.991436  13.153562  0.245756
# 1      83.277412   56.462780   0.623000  96.823723  70.338356  0.464067
# 2       0.997732    0.812314  -0.003963   1.043339   0.891402 -0.252149
# 3      64.316452   43.024647   0.775130  63.825657  44.809402  0.767117
# 4       4.696808    3.058579   0.871606   5.904472   3.929081  0.851887
# 5      43.441471   26.053858   0.743754  42.143089  26.702225  0.741234
# 6      44.127270   21.088480   0.735600  43.750076  23.092395  0.721123
# 7       0.645014    0.379025   0.013476   0.669590   0.409612 -0.007446
# 8       2.242872    1.703355   0.987665        NaN        NaN       NaN
# 9       0.506060    0.383949   0.398239        NaN        NaN       NaN
# 10    445.588970   13.110221   0.975742        NaN        NaN       NaN
# 11  18075.938116  104.513856   0.018472        NaN        NaN       NaN
# 12      1.499698    0.987240  -0.519163        NaN        NaN       NaN
# 13      1.046989    0.850183  -0.105783        NaN        NaN       NaN
# 14      0.564933    0.443428   0.678127        NaN        NaN       NaN
# 15      0.995630    0.813519   0.001380        NaN        NaN       NaN
# 16   6965.436035   74.394615 -16.079952        NaN        NaN       NaN
# 17      2.067983    1.585047   0.989513        NaN        NaN       NaN
#
#        test_rmse    test_mae    test_r2                      folder_name  \
# 0      15.352223   11.381064   0.267059                    cnn2dlstm_PET
# 1     101.788948   71.798531   0.515878                    cnn2dlstm_PRE
# 2       1.107618    0.934870  -0.136553                   cnn2dlstm_SPEI
# 3      72.938461   50.582729   0.751420                   cnn2dlstm_test
# 4       4.763505    3.260989   0.873663                   CNN3D_test_PET
# 5      44.679797   28.346233   0.706057                   CNN3D_test_PRE
# 6      50.558461   27.208007   0.623619                   CNN3D_test_Run
# 7       0.651818    0.395769  -0.001749                  CNN3D_test_SPEI
# 8       7.115232    5.337263   0.842564   PET_Forecasting_Global_XGBoost
# 9       0.538402    0.425542   0.504844  PRE_ConvLSTM_EncoderDecoder_Run
# 10    839.782582   17.202585   0.960761   PRE_Forecasting_Global_XGBoost
# 11  16323.513174  104.363764   0.012735              PRE_LSTM_Global_Run
# 12      1.691156    1.067154  -1.255846            SPEI_CNN1D_Global_Run
# 13      1.129393    0.936347  -0.181678            SPEI_CNN3D_Global_Run
# 14      1.063857    0.885687  -0.048518  SPEI_Forecasting_Global_XGBoost
# 15      0.878985    0.795628  -0.040174             SPEI_LSTM_Global_Run
# 16   6782.065918   73.031639 -20.090580            test_CNN3D_Global_Run
# 17      7.302454    5.595989   0.834170  test_Forecasting_Global_XGBoost
#
#                                           source_path  validation_rmse  \
# 0   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 1   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 2   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 3   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 4   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 5   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 6   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 7   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...              NaN
# 8   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         6.183279
# 9   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         0.555342
# 10  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...       646.838748
# 11  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...     19076.156517
# 12  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         1.633447
# 13  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         1.053275
# 14  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         0.961962
# 15  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         1.031030
# 16  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      7694.236816
# 17  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...         6.333017
#
#     validation_mae  validation_r2  train_mse   train_mape  validation_mse  \
# 0              NaN            NaN        NaN          NaN             NaN
# 1              NaN            NaN        NaN          NaN             NaN
# 2              NaN            NaN        NaN          NaN             NaN
# 3              NaN            NaN        NaN          NaN             NaN
# 4              NaN            NaN        NaN          NaN             NaN
# 5              NaN            NaN        NaN          NaN             NaN
# 6              NaN            NaN        NaN          NaN             NaN
# 7              NaN            NaN        NaN          NaN             NaN
# 8         4.537861       0.910912        NaN          NaN             NaN
# 9         0.449461       0.355468   0.256097  186188864.0        0.308405
# 10       13.975708       0.966447        NaN          NaN             NaN
# 11      106.985327       0.010471        NaN          NaN             NaN
# 12        1.002452      -1.065127        NaN          NaN             NaN
# 13        0.893532      -0.276111        NaN          NaN             NaN
# 14        0.830690      -0.064439        NaN          NaN             NaN
# 15        0.852902      -0.134666        NaN          NaN             NaN
# 16       79.138405     -16.928562        NaN          NaN             NaN
# 17        4.713589       0.906545        NaN          NaN             NaN
#
#     validation_mape  test_mse    test_mape
# 0               NaN       NaN          NaN
# 1               NaN       NaN          NaN
# 2               NaN       NaN          NaN
# 3               NaN       NaN          NaN
# 4               NaN       NaN          NaN
# 5               NaN       NaN          NaN
# 6               NaN       NaN          NaN
# 7               NaN       NaN          NaN
# 8               NaN       NaN          NaN
# 9        195.039078  0.289877  1235246.125
# 10              NaN       NaN          NaN
# 11              NaN       NaN          NaN
# 12              NaN       NaN          NaN
# 13              NaN       NaN          NaN
# 14              NaN       NaN          NaN
# 15              NaN       NaN          NaN
# 16              NaN       NaN          NaN
# 17              NaN       NaN          NaN

# %%
# %pwd
# Out:
# 'c:\\Users\\peera\\Desktop\\DroughtLSTM_oneday\\visualize'

# %%
# read json file at specified path
json_path = '../run_outputs/PRE_ConvLSTM_EncoderDecoder_Run/global_convlstm_improved_metrics.json'
with open(json_path, 'r') as f:
    pet_metrics = json.load(f)
#
pet_metrics = {
    "train": {
        "pre": {
            "rmse": 14.690605971456513,
            "mae": 9.997435569763184,
            "r2": 0.9876049160957336,
            "mse": 215.81390380859375,
            "mape": 2088715264.0
        },
        "pet": {
            "rmse": 4.513187793505633,
            "mae": 3.326540231704712,
            "r2": 0.9872914552688599,
            "mse": 20.368864059448242,
            "mape": 1578545408.0
        }
    },
    "validation": {
        "pre": {
            "rmse": 11.425516156112762,
            "mae": 8.765296936035156,
            "r2": 0.992537260055542,
            "mse": 130.54241943359375,
            "mape": 1463109248.0
        },
        "pet": {
            "rmse": 4.682781642217733,
            "mae": 3.6455321311950684,
            "r2": 0.9489039182662964,
            "mse": 21.928443908691406,
            "mape": 3.489358425140381
        }
    },
    "test": {
        "pre": {
            "rmse": 65.13356544559994,
            "mae": 45.16815948486328,
            "r2": 0.8017730116844177,
            "mse": 4242.38134765625,
            "mape": 124625352.0
        },
        "pet": {
            "rmse": 7.461358534831491,
            "mae": 5.850528240203857,
            "r2": 0.8268740177154541,
            "mse": 55.671871185302734,
            "mape": 5.565570831298828
        }
    }
} 
# Add PET ConvLSTM metrics to df_metrics with the same structure
pet_metrics_flat = {
    "train_rmse": pet_metrics['train']['pet']['rmse'],
    "train_mae": pet_metrics['train']['pet']['mae'],
    "train_r2": pet_metrics['train']['pet']['r2'],
    "validation_rmse": pet_metrics['validation']['pet']['rmse'],
    "validation_mae": pet_metrics['validation']['pet']['mae'],
    "validation_r2": pet_metrics['validation']['pet']['r2'],
    "test_rmse": pet_metrics['test']['pet']['rmse'],
    "test_mae": pet_metrics['test']['pet']['mae'],
    "test_r2": pet_metrics['test']['pet']['r2']
}
pet_metrics_flat['folder_name'] = 'PET_ConvLSTM-MultiTask'
# Add the PET ConvLSTM row to the DataFrame
df_metrics = pd.concat([df_metrics, pd.DataFrame([pet_metrics_flat])])
# Do for PRE as well
pre_metrics_flat = {
    "train_rmse": pet_metrics['train']['pre']['rmse'],
    "train_mae": pet_metrics['train']['pre']['mae'],
    "train_r2": pet_metrics['train']['pre']['r2'],
    "validation_rmse": pet_metrics['validation']['pre']['rmse'],
    "validation_mae": pet_metrics['validation']['pre']['mae'],
    "validation_r2": pet_metrics['validation']['pre']['r2'],
    "test_rmse": pet_metrics['test']['pre']['rmse'],
    "test_mae": pet_metrics['test']['pre']['mae'],
    "test_r2": pet_metrics['test']['pre']['r2']
}
# Add the PRE ConvLSTM metrics to the DataFrame and set index to 'PRE_ConvLSTM-MultiTask'
pre_metrics_flat['folder_name'] = 'PRE_ConvLSTM-MultiTask'
df_metrics = pd.concat([df_metrics, pd.DataFrame([pre_metrics_flat])])

# %%
pet_metrics_flat
# Out:
# {'train_rmse': 4.513187793505633,
#  'train_mae': 3.326540231704712,
#  'train_r2': 0.9872914552688599,
#  'validation_rmse': 4.682781642217733,
#  'validation_mae': 3.6455321311950684,
#  'validation_r2': 0.9489039182662964,
#  'test_rmse': 7.461358534831491,
#  'test_mae': 5.850528240203857,
#  'test_r2': 0.8268740177154541,
#  'folder_name': 'PET_ConvLSTM-MultiTask'}

# %%
pre_metrics_flat
# Out:
# {'train_rmse': 14.690605971456513,
#  'train_mae': 9.997435569763184,
#  'train_r2': 0.9876049160957336,
#  'validation_rmse': 11.425516156112762,
#  'validation_mae': 8.765296936035156,
#  'validation_r2': 0.992537260055542,
#  'test_rmse': 65.13356544559994,
#  'test_mae': 45.16815948486328,
#  'test_r2': 0.8017730116844177,
#  'folder_name': 'PRE_ConvLSTM-MultiTask'}

# %%
df_metrics
# Out:
#                                             train_pre  \
# 0   {'rmse': 80.94364166259766, 'mae': 49.33219528...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 14.690605971456513, 'mae': 9.99743556...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                             train_pet  \
# 0   {'rmse': 12.879279136657715, 'mae': 9.34953784...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 4.513187793505633, 'mae': 3.326540231...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                        validation_pre  \
# 0   {'rmse': 85.77197265625, 'mae': 54.13793563842...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 11.425516156112762, 'mae': 8.76529693...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                        validation_pet  \
# 0   {'rmse': 14.388618469238281, 'mae': 10.7275314...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 4.682781642217733, 'mae': 3.645532131...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                              test_pre  \
# 0   {'rmse': 96.06477355957031, 'mae': 61.43213272...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 65.13356544559994, 'mae': 45.16815948...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                              test_pet  \
# 0   {'rmse': 13.896890640258789, 'mae': 10.5460166...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 7.461358534831491, 'mae': 5.850528240...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                    folder_name  \
# 0   Advanced_PRE_PET_Multitask
# 1                 PET_ConvLSTM
# 2           PET_Global_XGBoost
# 3              PET_LSTM_Global
# 4                 PRE_ConvLSTM
# 5           PRE_Global_XGBoost
# 6              PRE_LSTM_Global
# 7   PRE_PET_ConvLSTM-MultiTask
# 8         SPEI_ConvLSTM_Direct
# 9          SPEI_Global_XGBoost
# 10            SPEI_LSTM_Global
# 0       PET_ConvLSTM-MultiTask
# 0       PRE_ConvLSTM-MultiTask
#
#                                           source_path    train_rmse  \
# 0   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...           NaN
# 1   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      5.179156
# 2   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      2.184229
# 3   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...    370.519167
# 4   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...     47.902183
# 5   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...     11.241125
# 6   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...  16836.368068
# 7   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...           NaN
# 8   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      0.911077
# 9   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      0.205586
# 10  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      0.983780
# 0                                                 NaN      4.513188
# 0                                                 NaN     14.690606
#
#      train_mae  ...  validation_r2     test_rmse    test_mae   test_r2  \
# 0          NaN  ...            NaN           NaN         NaN       NaN
# 1     3.776540  ...       0.911669      6.290103    4.526724  0.887249
# 2     1.656260  ...       0.983769      3.022044    2.183661  0.971599
# 3    15.168113  ...       0.071295    348.017200   14.300874  0.076689
# 4    28.866083  ...       0.881543     60.745692   40.709705  0.827581
# 5     7.548360  ...       0.972541     23.620501   13.924363  0.973931
# 6   100.419776  ...       0.073655  15156.888718  100.603804  0.083294
# 7          NaN  ...            NaN           NaN         NaN       NaN
# 8     0.691937  ...       0.081962      1.006960    0.840835  0.060636
# 9     0.155081  ...       0.910303      0.260043    0.203647  0.937353
# 10    0.808711  ...      -0.092436      0.869378    0.790397 -0.028805
# 0     3.326540  ...       0.948904      7.461359    5.850528  0.826874
# 0     9.997436  ...       0.992537     65.133565   45.168159  0.801773
#
#       train_mse    train_mape  validation_mse  validation_mape     test_mse  \
# 0           NaN           NaN             NaN              NaN          NaN
# 1           NaN           NaN             NaN              NaN          NaN
# 2           NaN           NaN             NaN              NaN          NaN
# 3           NaN           NaN             NaN              NaN          NaN
# 4   2294.619141  4.412368e+09     2072.110840     1.920655e+09  3690.039062
# 5           NaN           NaN             NaN              NaN          NaN
# 6           NaN           NaN             NaN              NaN          NaN
# 7           NaN           NaN             NaN              NaN          NaN
# 8      0.830062  8.988048e+07        0.798097     2.219772e+02     1.013969
# 9           NaN           NaN             NaN              NaN          NaN
# 10          NaN           NaN             NaN              NaN          NaN
# 0           NaN           NaN             NaN              NaN          NaN
# 0           NaN           NaN             NaN              NaN          NaN
#
#        test_mape
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4   1.442326e+08
# 5            NaN
# 6            NaN
# 7            NaN
# 8   1.947315e+02
# 9            NaN
# 10           NaN
# 0            NaN
# 0            NaN
#
# [13 rows x 23 columns]

# %%
#drop PRE_PET_ConvLSTM-MultiTask row in index
if 'PRE_PET_ConvLSTM-MultiTask' in df_metrics["folder_name"]:
    print("Dropping PRE_PET_ConvLSTM-MultiTask row from index")
    df_metrics = df_metrics.drop('PRE_PET_ConvLSTM-MultiTask')

# %%
df_metrics
# Out:
#                                             train_pre  \
# 0   {'rmse': 80.94364166259766, 'mae': 49.33219528...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 14.690605971456513, 'mae': 9.99743556...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                             train_pet  \
# 0   {'rmse': 12.879279136657715, 'mae': 9.34953784...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 4.513187793505633, 'mae': 3.326540231...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                        validation_pre  \
# 0   {'rmse': 85.77197265625, 'mae': 54.13793563842...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 11.425516156112762, 'mae': 8.76529693...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                        validation_pet  \
# 0   {'rmse': 14.388618469238281, 'mae': 10.7275314...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 4.682781642217733, 'mae': 3.645532131...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                              test_pre  \
# 0   {'rmse': 96.06477355957031, 'mae': 61.43213272...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 65.13356544559994, 'mae': 45.16815948...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                              test_pet  \
# 0   {'rmse': 13.896890640258789, 'mae': 10.5460166...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'rmse': 7.461358534831491, 'mae': 5.850528240...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                    folder_name  \
# 0   Advanced_PRE_PET_Multitask
# 1                 PET_ConvLSTM
# 2           PET_Global_XGBoost
# 3              PET_LSTM_Global
# 4                 PRE_ConvLSTM
# 5           PRE_Global_XGBoost
# 6              PRE_LSTM_Global
# 7   PRE_PET_ConvLSTM-MultiTask
# 8         SPEI_ConvLSTM_Direct
# 9          SPEI_Global_XGBoost
# 10            SPEI_LSTM_Global
# 0       PET_ConvLSTM-MultiTask
# 0       PRE_ConvLSTM-MultiTask
#
#                                           source_path    train_rmse  \
# 0   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...           NaN
# 1   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      5.179156
# 2   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      2.184229
# 3   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...    370.519167
# 4   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...     47.902183
# 5   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...     11.241125
# 6   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...  16836.368068
# 7   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...           NaN
# 8   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      0.911077
# 9   c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      0.205586
# 10  c:\Users\peera\Desktop\DroughtLSTM_oneday\visu...      0.983780
# 0                                                 NaN      4.513188
# 0                                                 NaN     14.690606
#
#      train_mae  ...  validation_r2     test_rmse    test_mae   test_r2  \
# 0          NaN  ...            NaN           NaN         NaN       NaN
# 1     3.776540  ...       0.911669      6.290103    4.526724  0.887249
# 2     1.656260  ...       0.983769      3.022044    2.183661  0.971599
# 3    15.168113  ...       0.071295    348.017200   14.300874  0.076689
# 4    28.866083  ...       0.881543     60.745692   40.709705  0.827581
# 5     7.548360  ...       0.972541     23.620501   13.924363  0.973931
# 6   100.419776  ...       0.073655  15156.888718  100.603804  0.083294
# 7          NaN  ...            NaN           NaN         NaN       NaN
# 8     0.691937  ...       0.081962      1.006960    0.840835  0.060636
# 9     0.155081  ...       0.910303      0.260043    0.203647  0.937353
# 10    0.808711  ...      -0.092436      0.869378    0.790397 -0.028805
# 0     3.326540  ...       0.948904      7.461359    5.850528  0.826874
# 0     9.997436  ...       0.992537     65.133565   45.168159  0.801773
#
#       train_mse    train_mape  validation_mse  validation_mape     test_mse  \
# 0           NaN           NaN             NaN              NaN          NaN
# 1           NaN           NaN             NaN              NaN          NaN
# 2           NaN           NaN             NaN              NaN          NaN
# 3           NaN           NaN             NaN              NaN          NaN
# 4   2294.619141  4.412368e+09     2072.110840     1.920655e+09  3690.039062
# 5           NaN           NaN             NaN              NaN          NaN
# 6           NaN           NaN             NaN              NaN          NaN
# 7           NaN           NaN             NaN              NaN          NaN
# 8      0.830062  8.988048e+07        0.798097     2.219772e+02     1.013969
# 9           NaN           NaN             NaN              NaN          NaN
# 10          NaN           NaN             NaN              NaN          NaN
# 0           NaN           NaN             NaN              NaN          NaN
# 0           NaN           NaN             NaN              NaN          NaN
#
#        test_mape
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4   1.442326e+08
# 5            NaN
# 6            NaN
# 7            NaN
# 8   1.947315e+02
# 9            NaN
# 10           NaN
# 0            NaN
# 0            NaN
#
# [13 rows x 23 columns]

# %%
df_metrics = df_metrics[["train_rmse", "train_mae", "train_r2",
                           "validation_rmse", "validation_mae", "validation_r2",
                           "test_rmse", "test_mae", "test_r2", "folder_name"]]

# %%
df_metrics.dropna(inplace=True)
# Out:
# C:\Users\peera\AppData\Local\Temp\ipykernel_32780\3536202067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metrics.dropna(inplace=True)

# %%
df_metrics
# Out:
#       train_rmse   train_mae  train_r2  validation_rmse  validation_mae  \
# 1       5.179156    3.776540  0.934317         5.677805        4.586584
# 2       2.184229    1.656260  0.988275         2.681794        2.047693
# 3     370.519167   15.168113  0.092129       411.508014       15.792475
# 4      47.902183   28.866083  0.868505        45.520444       30.449352
# 5      11.241125    7.548360  0.993121        23.007908       12.048899
# 6   16836.368068  100.419776  0.085781     17858.082447      102.802775
# 8       0.911077    0.691937  0.026297         0.893363        0.741511
# 9       0.205586    0.155081  0.957293         0.285489        0.218081
# 10      0.983780    0.808711  0.013266         0.992658        0.837766
# 0       4.513188    3.326540  0.987291         4.682782        3.645532
# 0      14.690606    9.997436  0.987605        11.425516        8.765297
#
#     validation_r2     test_rmse    test_mae   test_r2             folder_name
# 1        0.911669      6.290103    4.526724  0.887249            PET_ConvLSTM
# 2        0.983769      3.022044    2.183661  0.971599      PET_Global_XGBoost
# 3        0.071295    348.017200   14.300874  0.076689         PET_LSTM_Global
# 4        0.881543     60.745692   40.709705  0.827581            PRE_ConvLSTM
# 5        0.972541     23.620501   13.924363  0.973931      PRE_Global_XGBoost
# 6        0.073655  15156.888718  100.603804  0.083294         PRE_LSTM_Global
# 8        0.081962      1.006960    0.840835  0.060636    SPEI_ConvLSTM_Direct
# 9        0.910303      0.260043    0.203647  0.937353     SPEI_Global_XGBoost
# 10      -0.092436      0.869378    0.790397 -0.028805        SPEI_LSTM_Global
# 0        0.948904      7.461359    5.850528  0.826874  PET_ConvLSTM-MultiTask
# 0        0.992537     65.133565   45.168159  0.801773  PRE_ConvLSTM-MultiTask

# %%
#aligin to make folder_name column to be the most left column before the metrics
df_metrics = df_metrics.set_index('folder_name')
df_metrics = df_metrics.reset_index()

# %%
df_metrics
# Out:
#                folder_name    train_rmse   train_mae  train_r2  \
# 0             PET_ConvLSTM      5.179156    3.776540  0.934317
# 1       PET_Global_XGBoost      2.184229    1.656260  0.988275
# 2          PET_LSTM_Global    370.519167   15.168113  0.092129
# 3             PRE_ConvLSTM     47.902183   28.866083  0.868505
# 4       PRE_Global_XGBoost     11.241125    7.548360  0.993121
# 5          PRE_LSTM_Global  16836.368068  100.419776  0.085781
# 6     SPEI_ConvLSTM_Direct      0.911077    0.691937  0.026297
# 7      SPEI_Global_XGBoost      0.205586    0.155081  0.957293
# 8         SPEI_LSTM_Global      0.983780    0.808711  0.013266
# 9   PET_ConvLSTM-MultiTask      4.513188    3.326540  0.987291
# 10  PRE_ConvLSTM-MultiTask     14.690606    9.997436  0.987605
#
#     validation_rmse  validation_mae  validation_r2     test_rmse    test_mae  \
# 0          5.677805        4.586584       0.911669      6.290103    4.526724
# 1          2.681794        2.047693       0.983769      3.022044    2.183661
# 2        411.508014       15.792475       0.071295    348.017200   14.300874
# 3         45.520444       30.449352       0.881543     60.745692   40.709705
# 4         23.007908       12.048899       0.972541     23.620501   13.924363
# 5      17858.082447      102.802775       0.073655  15156.888718  100.603804
# 6          0.893363        0.741511       0.081962      1.006960    0.840835
# 7          0.285489        0.218081       0.910303      0.260043    0.203647
# 8          0.992658        0.837766      -0.092436      0.869378    0.790397
# 9          4.682782        3.645532       0.948904      7.461359    5.850528
# 10        11.425516        8.765297       0.992537     65.133565   45.168159
#
#      test_r2
# 0   0.887249
# 1   0.971599
# 2   0.076689
# 3   0.827581
# 4   0.973931
# 5   0.083294
# 6   0.060636
# 7   0.937353
# 8  -0.028805
# 9   0.826874
# 10  0.801773

# %%
df_metrics.to_csv('results/global_convlstm_improved_full_metrics.csv', index=False)

# %%
# df_metrics_pre is the same as df_metrics but only contains the PRE metrics
df_metrics_pre = df_metrics[df_metrics['folder_name'].str.contains('PRE_')]
df_metrics_pet = df_metrics[df_metrics['folder_name'].str.contains('PET_')]
df_metrics_spei = df_metrics[df_metrics['folder_name'].str.contains('SPEI_')]

# %%
df_metrics_pre
# Out:
#                folder_name    train_rmse   train_mae  train_r2  \
# 3             PRE_ConvLSTM     47.902183   28.866083  0.868505
# 4       PRE_Global_XGBoost     11.241125    7.548360  0.993121
# 5          PRE_LSTM_Global  16836.368068  100.419776  0.085781
# 10  PRE_ConvLSTM-MultiTask     14.690606    9.997436  0.987605
#
#     validation_rmse  validation_mae  validation_r2     test_rmse    test_mae  \
# 3         45.520444       30.449352       0.881543     60.745692   40.709705
# 4         23.007908       12.048899       0.972541     23.620501   13.924363
# 5      17858.082447      102.802775       0.073655  15156.888718  100.603804
# 10        11.425516        8.765297       0.992537     65.133565   45.168159
#
#      test_r2
# 3   0.827581
# 4   0.973931
# 5   0.083294
# 10  0.801773

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load your CSV
df = df_metrics_pre

# Define metrics to plot
metrics_to_plot = {
    "RMSE": ["train_rmse", "validation_rmse", "test_rmse"],
    "MAE": ["train_mae", "validation_mae", "test_mae"],
    "R2": ["train_r2", "validation_r2", "test_r2"]
}

datasets = ["Train", "Validation", "Test"]
width = 0.25

# Sort by test RMSE
df_sorted = df.sort_values(by="test_rmse", ascending=True).reset_index(drop=True)
model_names = df_sorted['folder_name'].values
x = np.arange(len(model_names))

# Plot
for metric_name, cols in metrics_to_plot.items():
    plt.figure(figsize=(12, 6))
    # if R^2 sort from high to low
    if metric_name == "R2":
        df_sorted = df_sorted.sort_values(by="test_r2", ascending=False).reset_index(drop=True)
        model_names = df_sorted['folder_name'].values
        x = np.arange(len(model_names))
    else:
        df_sorted = df_sorted.sort_values(by="test_rmse", ascending=True).reset_index(drop=True)
        model_names = df_sorted['folder_name'].values
        x = np.arange(len(model_names))
    for i, col in enumerate(cols):
        plt.bar(x + i * width, df_sorted[col], width=width, label=datasets[i])
    plt.xticks(x + width, model_names, rotation=45, ha='right')
    plt.ylabel(metric_name)
    plt.title(f"{metric_name} Comparison Across Models (Sorted by Test RMSE)")
    plt.legend()
    if metric_name == "RMSE":
        plt.yscale('log')
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load your CSV
df = df_metrics_pet

# Define metrics to plot
metrics_to_plot = {
    "RMSE": ["train_rmse", "validation_rmse", "test_rmse"],
    "MAE": ["train_mae", "validation_mae", "test_mae"],
    "R2": ["train_r2", "validation_r2", "test_r2"]
}

datasets = ["Train", "Validation", "Test"]
width = 0.25

# Sort by test RMSE
df_sorted = df.sort_values(by="test_rmse", ascending=True).reset_index(drop=True)
model_names = df_sorted['folder_name'].values
x = np.arange(len(model_names))

# Plot
for metric_name, cols in metrics_to_plot.items():
    plt.figure(figsize=(12, 6))
    # if R^2 sort from high to low
    if metric_name == "R2":
        df_sorted = df_sorted.sort_values(by="test_r2", ascending=False).reset_index(drop=True)
        model_names = df_sorted['folder_name'].values
        x = np.arange(len(model_names))
    else:
        df_sorted = df_sorted.sort_values(by="test_rmse", ascending=True).reset_index(drop=True)
        model_names = df_sorted['folder_name'].values
        x = np.arange(len(model_names))
    for i, col in enumerate(cols):
        plt.bar(x + i * width, df_sorted[col], width=width, label=datasets[i])
    plt.xticks(x + width, model_names, rotation=45, ha='right')
    plt.ylabel(metric_name)
    plt.title(f"{metric_name} Comparison Across Models (Sorted by Test RMSE)")
    plt.legend()
    if metric_name == "RMSE":
        plt.yscale('log')
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # SPEI

# %%
spei_multi = pd.read_csv('results/spei_multiconv.csv')
spei_single = pd.read_csv('results/spei_singleconv.csv')
spei_raw = pd.read_csv('../data/full.csv')
spei_raw.head()
# Ensure 'time' columns are in datetime format for accurate merging
spei_multi['time'] = pd.to_datetime(spei_multi['time'])
#rename the 'spei' column to 'spei_predicted'
spei_multi.rename(columns={'spei': 'spei_predicted'}, inplace=True)
spei_single.rename(columns={'spei': 'spei_predicted'}, inplace=True)

# %%
spei_multi
# Out:
#              time    lat     lon         pre  pre_predicted  \
# 0      1902-01-16   6.25  101.25   81.000000      81.520270
# 1      1902-01-16   6.25  101.75  127.000000     141.740220
# 2      1902-01-16   6.75   99.75   43.600002      49.503430
# 3      1902-01-16   6.75  100.25   40.500000      46.687220
# 4      1902-01-16   6.75  100.75   43.100002      50.814670
# ...           ...    ...     ...         ...            ...
# 262051 2023-12-16  19.75   99.25    3.100000     135.059340
# 262052 2023-12-16  19.75   99.75    1.900000      82.253090
# 262053 2023-12-16  19.75  100.25    2.100000      31.048088
# 262054 2023-12-16  20.25   99.75    3.300000     118.458090
# 262055 2023-12-16  20.25  100.25    2.600000      75.785490
#
#         pre_prediction_error  pre_absolute_error    pet  pet_predicted  \
# 0                   0.520271            0.520271  102.3     106.799460
# 1                  14.740219           14.740219   99.2     104.200905
# 2                   5.903427            5.903427  127.1     129.733500
# 3                   6.187221            6.187221  117.8     119.497795
# 4                   7.714668            7.714668  108.5     113.688970
# ...                      ...                 ...    ...            ...
# 262051            131.959340          131.959340   74.4      70.887184
# 262052             80.353090           80.353090   74.4      65.058340
# 262053             28.948088           28.948088   74.4      68.492600
# 262054            115.158090          115.158090   71.3      68.728070
# 262055             73.185490           73.185490   71.3      69.556330
#
#         pet_prediction_error  pet_absolute_error  spei_predicted
# 0                   4.499458            4.499458       -0.462184
# 1                   5.000908            5.000908       -0.103014
# 2                   2.633507            2.633507        0.112876
# 3                   1.697792            1.697792        0.113577
# 4                   5.188973            5.188973       -0.340741
# ...                      ...                 ...             ...
# 262051             -3.512817            3.512817        2.835077
# 262052             -9.341660            9.341660        2.530852
# 262053             -5.907402            5.907402        1.753237
# 262054             -2.571930            2.571930        2.706575
# 262055             -1.743675            1.743675        2.501216
#
# [262056 rows x 12 columns]

# %%
#print nan
print(spei_multi.isna().sum())
print(spei_single.isna().sum())

#show row data has nan
print(spei_multi[spei_multi.isna().any(axis=1)])
print(spei_single[spei_single.isna().any(axis=1)])
# Out:
# time                    0
# lat                     0
# lon                     0
# pre                     0
# pre_predicted           0
# pre_prediction_error    0
# pre_absolute_error      0
# pet                     0
# pet_predicted           0
# pet_prediction_error    0
# pet_absolute_error      0
# spei_predicted          0
# spei                    3
# dtype: int64
# time                  0
# lat                   0
# lon                   0
# pre                   0
# pre_predicted         0
# prediction_error_x    0
# absolute_error_x      0
# pet                   0
# pet_predicted         0
# prediction_error_y    0
# absolute_error_y      0
# spei_predicted        0
# spei                  3
# dtype: int64
#              time    lat     lon  pre  pre_predicted  pre_prediction_error  \
# 96580  1946-12-16  15.75  105.25  0.0       5.667066              5.667066
# 96618  1946-12-16  17.25  104.75  0.0       5.434554              5.434554
# 103177 1950-01-16  15.25   99.25  0.0       7.363619              7.363619
#
#         pre_absolute_error  pet  pet_predicted  pet_prediction_error  \
# 96580             5.667066  0.0     114.374626            114.374626
# 96618             5.434554  0.0     104.476906            104.476906
# 103177            7.363619  0.0     102.519720            102.519720
#
#         pet_absolute_error  spei_predicted  spei
# 96580           114.374626       -0.984982   NaN
# 96618           104.476906       -0.824232   NaN
# 103177          102.519720       -0.035767   NaN
#              time    lat     lon  pre  pre_predicted  prediction_error_x  \
# 96580  1946-12-16  15.75  105.25  0.0       7.009390            7.009390
# 96618  1946-12-16  17.25  104.75  0.0       2.712431            2.712431
# 103177 1950-01-16  15.25   99.25  0.0       5.096325            5.096325
#
#         absolute_error_x  pet  pet_predicted  prediction_error_y  \
# 96580           7.009390  0.0      118.05468           118.05468
# 96618           2.712431  0.0      105.91504           105.91504
# 103177          5.096325  0.0      104.44695           104.44695
#
#         absolute_error_y  spei_predicted  spei
# 96580          118.05468       -1.412577   NaN
# 96618          105.91504       -1.357435   NaN
# 103177         104.44695       -1.296200   NaN

# %%
# Ensure 'time' columns are in datetime format for accurate merging
spei_multi['time'] = pd.to_datetime(spei_multi['time'])
spei_single['time'] = pd.to_datetime(spei_single['time'])
# Rename the 'spei' column to 'spei_predicted'
spei_raw['time'] = pd.to_datetime(spei_raw['time'])

# Only keep necessary columns for merging
spei_raw_subset = spei_raw[['lat', 'lon', 'time', 'spei']]

# Merge on ['lat', 'lon', 'time']
spei_multi = spei_multi.merge(spei_raw_subset, on=['lat', 'lon', 'time'], how='left')
spei_single = spei_single.merge(spei_raw_subset, on=['lat', 'lon', 'time'], how='left')

# Preview result
print(spei_multi.head())
# Out:
#         time   lat     lon         pre  pre_predicted  pre_prediction_error  \
# 0 1902-01-16  6.25  101.25   81.000000       81.52027              0.520271
# 1 1902-01-16  6.25  101.75  127.000000      141.74022             14.740219
# 2 1902-01-16  6.75   99.75   43.600002       49.50343              5.903427
# 3 1902-01-16  6.75  100.25   40.500000       46.68722              6.187221
# 4 1902-01-16  6.75  100.75   43.100002       50.81467              7.714668
#
#    pre_absolute_error    pet  pet_predicted  pet_prediction_error  \
# 0            0.520271  102.3     106.799460              4.499458
# 1           14.740219   99.2     104.200905              5.000908
# 2            5.903427  127.1     129.733500              2.633507
# 3            6.187221  117.8     119.497795              1.697792
# 4            7.714668  108.5     113.688970              5.188973
#
#    pet_absolute_error  spei_predicted      spei
# 0            4.499458       -0.462184 -0.322998
# 1            5.000908       -0.103014 -0.347505
# 2            2.633507        0.112876 -0.164277
# 3            1.697792        0.113577 -0.242470
# 4            5.188973       -0.340741 -0.519982

# %%
spei_multi.head()
spei_single.head()
#save the merged dataframes to csv
spei_multi.to_csv('results/spei_multi_merged.csv', index=False)
spei_single.to_csv('results/spei_single_merged.csv', index=False)

# %%
def calculate_metrics(df):
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

    y_true = df['spei'].values
    y_pred = df['spei_predicted'].values

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    return {
        "rmse": rmse,
        "mae": mae,
        "r2": r2
    }

# %%
train.isna().sum()
# Out:
# time                    0
# lat                     0
# lon                     0
# pre                     0
# pre_predicted           0
# pre_prediction_error    0
# pre_absolute_error      0
# pet                     0
# pet_predicted           0
# pet_prediction_error    0
# pet_absolute_error      0
# spei_predicted          0
# spei                    3
# dtype: int64

# %%
# seperate train,val,test based on given time value ending such as "2017-01-16"
train = spei_multi[spei_multi['time'] < '2017-01-16']
val = spei_multi[(spei_multi['time'] >= '2017-01-16') & (spei_multi['time'] < '2020-01-16')]
test = spei_multi[spei_multi['time'] >= '2020-01-16']
train_metrics = calculate_metrics(train)
val_metrics = calculate_metrics(val)
test_metrics = calculate_metrics(test)
val_metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 5
#       3 val = spei_multi[(spei_multi['time'] >= '2017-01-16') & (spei_multi['time'] < '2020-01-16')]
#       4 test = spei_multi[spei_multi['time'] >= '2020-01-16']
# ----> 5 train_metrics = calculate_metrics(train)
#       6 val_metrics = calculate_metrics(val)
#       7 test_metrics = calculate_metrics(test)
#
# Cell In[34], line 7, in calculate_metrics(df)
#       4 y_true = df['spei'].values
#       5 y_pred = df['spei_predicted'].values
# ----> 7 rmse = np.sqrt(mean_squared_error(y_true, y_pred))
#       8 mae = mean_absolute_error(y_true, y_pred)
#       9 r2 = r2_score(y_true, y_pred)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\sklearn\metrics\_regression.py:506, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     501     if not squared:
#     502         return root_mean_squared_error(
#     503             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     504         )
# --> 506 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     507     y_true, y_pred, multioutput
#     508 )
#     509 check_consistent_length(y_true, y_pred, sample_weight)
#     510 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\sklearn\metrics\_regression.py:112, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#     109 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
#     111 check_consistent_length(y_true, y_pred)
# --> 112 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     113 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     115 if y_true.ndim == 1:
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\sklearn\utils\validation.py:1064, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#    1063 if force_all_finite:
# -> 1064     _assert_all_finite(
#    1065         array,
#    1066         input_name=input_name,
#    1067         estimator_name=estimator_name,
#    1068         allow_nan=force_all_finite == "allow-nan",
#    1069     )
#    1071 if copy:
#    1072     if _is_numpy_namespace(xp):
#    1073         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\sklearn\utils\validation.py:123, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120 if first_pass_isfinite:
#     121     return
# --> 123 _assert_all_finite_element_wise(
#     124     X,
#     125     xp=xp,
#     126     allow_nan=allow_nan,
#     127     msg_dtype=msg_dtype,
#     128     estimator_name=estimator_name,
#     129     input_name=input_name,
#     130 )
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\sklearn\utils\validation.py:172, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     155 if estimator_name and input_name == "X" and has_nan_error:
#     156     # Improve the error message on how to handle missing values in
#     157     # scikit-learn.
#     158     msg_err += (
#     159         f"\n{estimator_name} does not accept missing values"
#     160         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     170         "#estimators-that-handle-nan-values"
#     171     )
# --> 172 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
train_single = spei_single[spei_single['time'] < '2017-01-16']
val_single = spei_single[(spei_single['time'] >= '2017-01-16') & (spei_single['time'] < '2020-01-16')]
test_single = spei_single[spei_single['time'] >= '2020-01-16']
train_single_metrics = calculate_metrics(train_single)
val_single_metrics = calculate_metrics(val_single)
test_single_metrics = calculate_metrics(test_single)
val_single_metrics
# Out:
# {'rmse': np.float64(5.677804939387878),
#  'mae': np.float64(4.586583619801365),
#  'r2': 0.9116693412866181}

# %%
# add SPEI ConvLSTM metrics to df_metrics with the same structure
spei_multi_metrics_flat = {
    "train_rmse": train_metrics['rmse'],
    "train_mae": train_metrics['mae'],
    "train_r2": train_metrics['r2'],
    "validation_rmse": val_metrics['rmse'],
    "validation_mae": val_metrics['mae'],
    "validation_r2": val_metrics['r2'],
    "test_rmse": test_metrics['rmse'],
    "test_mae": test_metrics['mae'],
    "test_r2": test_metrics['r2']
}
spei_multi_metrics_flat['folder_name'] = 'SPEI_ConvLSTM-MultiTask'
# Add the SPEI ConvLSTM row to the DataFrame
df_metrics = pd.concat([df_metrics, pd.DataFrame([spei_multi_metrics_flat])])
# Add SPEI Single ConvLSTM metrics to df_metrics with the same structure
spei_single_metrics_flat = {
    "train_rmse": train_single_metrics['rmse'],
    "train_mae": train_single_metrics['mae'],
    "train_r2": train_single_metrics['r2'],
    "validation_rmse": val_single_metrics['rmse'],
    "validation_mae": val_single_metrics['mae'],
    "validation_r2": val_single_metrics['r2'],
    "test_rmse": test_single_metrics['rmse'],
    "test_mae": test_single_metrics['mae'],
    "test_r2": test_single_metrics['r2']
}
spei_single_metrics_flat['folder_name'] = 'SPEI_ConvLSTM-SingleTask'
# Add the SPEI Single ConvLSTM row to the DataFrame
df_metrics = pd.concat([df_metrics, pd.DataFrame([spei_single_metrics_flat])])
# Save the updated DataFrame to CSV
df_metrics.to_csv('results/global_convlstm_improved_full_metrics.csv', index=False)
df_metrics_spei = df_metrics[df_metrics['folder_name'].str.contains('SPEI_')]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load your CSV
df = df_metrics_spei

# Define metrics to plot
metrics_to_plot = {
    "RMSE": ["train_rmse", "validation_rmse", "test_rmse"],
    "MAE": ["train_mae", "validation_mae", "test_mae"],
    "R2": ["train_r2", "validation_r2", "test_r2"]
}

datasets = ["Train", "Validation", "Test"]
width = 0.25

# Sort by test RMSE
df_sorted = df.sort_values(by="test_rmse", ascending=True).reset_index(drop=True)
model_names = df_sorted['folder_name'].values
x = np.arange(len(model_names))

# Plot
for metric_name, cols in metrics_to_plot.items():
    plt.figure(figsize=(12, 6))
    # if R^2 sort from high to low
    if metric_name == "R2":
        df_sorted = df_sorted.sort_values(by="test_r2", ascending=False).reset_index(drop=True)
        model_names = df_sorted['folder_name'].values
        x = np.arange(len(model_names))
    else:
        df_sorted = df_sorted.sort_values(by="test_rmse", ascending=True).reset_index(drop=True)
        model_names = df_sorted['folder_name'].values
        x = np.arange(len(model_names))
    for i, col in enumerate(cols):
        plt.bar(x + i * width, df_sorted[col], width=width, label=datasets[i])
    plt.xticks(x + width, model_names, rotation=45, ha='right')
    plt.ylabel(metric_name)
    plt.title(f"{metric_name} Comparison Across Models (Sorted by Test RMSE)")
    plt.legend()
    if metric_name == "RMSE":
        plt.yscale('log')
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
# print df_metrics_spei sorted by test RMSE
df_metrics_spei_sorted = df_metrics_spei.sort_values(by="test_rmse", ascending=True)
df_metrics_spei_sorted
# Out:
#                 folder_name  train_rmse  train_mae  train_r2  validation_rmse  \
# 7       SPEI_Global_XGBoost    0.205586   0.155081  0.957293         0.285489
# 8          SPEI_LSTM_Global    0.983780   0.808711  0.013266         0.992658
# 6      SPEI_ConvLSTM_Direct    0.911077   0.691937  0.026297         0.893363
# 0  SPEI_ConvLSTM-SingleTask    5.179156   3.776540  0.934317         5.677805
# 0  SPEI_ConvLSTM-SingleTask    5.179156   3.776540  0.934317         5.677805
# 0   SPEI_ConvLSTM-MultiTask    4.693301   3.565561  0.946062         5.318447
# 0   SPEI_ConvLSTM-MultiTask    4.693301   3.565561  0.946062         5.318447
#
#    validation_mae  validation_r2  test_rmse  test_mae   test_r2
# 7        0.218081       0.910303   0.260043  0.203647  0.937353
# 8        0.837766      -0.092436   0.869378  0.790397 -0.028805
# 6        0.741511       0.081962   1.006960  0.840835  0.060636
# 0        4.586584       0.911669   6.290103  4.526724  0.887249
# 0        4.586584       0.911669   6.290103  4.526724  0.887249
# 0        4.154190       0.922497   6.920429  5.258085  0.863519
# 0        4.154190       0.922497   6.920429  5.258085  0.863519

# %%
df_metrics_spei_sorted.to_csv('results/spei_convlstm_improved_full_metrics.csv', index=False)
