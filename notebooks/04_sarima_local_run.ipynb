# %%
import sys
import os
import numpy as np
import pandas as pd

# Add project root to Python path to find 'src'
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    print(f"Added project root to sys.path: {project_root}")

# Import your new pipeline class
from src.sarima_pipeline import SarimaLocalPipeline

# %%
# Ensure this path is correct from your notebook's location
config_file = "../config/sarima/config_SARIMA_SPEI.yaml"

# Create an instance of the pipeline
sarima_pipeline = SarimaLocalPipeline(config_path=config_file)

# Execute the pipeline
all_sarima_metrics = sarima_pipeline.run_pipeline()
# Out:
# SARIMA Pipeline Class: Loading config from: c:\Users\peera\Desktop\DroughtLSTM_oneday\config\sarima\config_SARIMA_SPEI.yaml
# Configuration loaded from c:\Users\peera\Desktop\DroughtLSTM_oneday\config\sarima\config_SARIMA_SPEI.yaml
# SARIMA Pipeline Class: Artifacts will be saved under 'c:\Users\peera\Desktop\DroughtLSTM_oneday\config\sarima\../../run_outputs\SPEI_SARIMA_Local_Run_sarima_local'
#
# --- Starting SARIMA Local Pipeline Run: Experiment 'SPEI_SARIMA_Local_Run_sarima_local' ---
# SARIMA Pipeline: Loading full raw data...
# Successfully loaded data from c:\Users\peera\Desktop\DroughtLSTM_oneday\data\full.csv. Shape: (264204, 19)
# Converted column 'time' to datetime.
# Data sorted by ['time', 'lat', 'lon'].
# SARIMA Pipeline: Found 179 unique locations.
#
# --- Processing Location: lat6.25_lon101.25 ---
#   Warning: Could not infer frequency for lat6.25_lon101.25.
#   Stationarity (p-value): 0.0000 -> Stationary
#   Running auto_arima with seasonal period m=12...
#   Best model found for lat6.25_lon101.25: (3, 0, 0) (2, 1, 1, 12)
# c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#   lat6.25_lon101.25 - Train Set:      RMSE=0.9996, MAE=0.8147, R2=-0.0276
#   lat6.25_lon101.25 - Validation Set: RMSE=1.4941, MAE=1.0645, R2=-0.0505
#   lat6.25_lon101.25 - Test Set:       RMSE=1.1804, MAE=0.8982, R2=-0.1063
#
# --- Processing Location: lat6.25_lon101.75 ---
#   Warning: Could not infer frequency for lat6.25_lon101.75.
#   Stationarity (p-value): 0.0000 -> Stationary
#   Running auto_arima with seasonal period m=12...
#   Best model found for lat6.25_lon101.75: (2, 0, 0) (2, 1, 1, 12)
# c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#   lat6.25_lon101.75 - Train Set:      RMSE=0.9987, MAE=0.8109, R2=-0.0216
#   lat6.25_lon101.75 - Validation Set: RMSE=1.5159, MAE=1.0679, R2=-0.0361
#   lat6.25_lon101.75 - Test Set:       RMSE=1.1863, MAE=0.9057, R2=-0.1264
#
# --- Processing Location: lat6.75_lon99.75 ---
#   Warning: Could not infer frequency for lat6.75_lon99.75.
#   Stationarity (p-value): 0.0000 -> Stationary
#   Running auto_arima with seasonal period m=12...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 sarima_pipeline = SarimaLocalPipeline(config_path=config_file)
#       7 # Execute the pipeline
# ----> 8 all_sarima_metrics = sarima_pipeline.run_pipeline()
#
# File c:\Users\peera\Desktop\DroughtLSTM_oneday\src\sarima_pipeline.py:241, in SarimaLocalPipeline.run_pipeline(self)
#     235 location_data_df = self.full_raw_data[
#     236     (self.full_raw_data[lat_col] == lat) &
#     237     (self.full_raw_data[lon_col] == lon)
#     238 ].copy()
#     239 if location_data_df.empty: continue
# --> 241 metrics = self._process_location(loc_coords, location_data_df)
#     242 if metrics:
#     243     self.all_location_metrics.append(metrics)
#
# File c:\Users\peera\Desktop\DroughtLSTM_oneday\src\sarima_pipeline.py:146, in SarimaLocalPipeline._process_location(self, location_coords, location_data)
#     144 print(f"  Running auto_arima with seasonal period m={seasonal_period}...")
#     145 try:
# --> 146     sarima_model = self._run_auto_arima(train_data, seasonal_period)
#     147     print(f"  Best model found for {loc_identifier}: {sarima_model.order} {sarima_model.seasonal_order}")
#     148 except Exception as e:
#
# File c:\Users\peera\Desktop\DroughtLSTM_oneday\src\sarima_pipeline.py:78, in SarimaLocalPipeline._run_auto_arima(self, train_data, seasonal_period, exogenous_data)
#      76 def _run_auto_arima(self, train_data, seasonal_period, exogenous_data=None):
#      77     """Uses pmdarima.auto_arima to find the best SARIMA/SARIMAX model."""
# ---> 78     model = pm.auto_arima(
#      79         y=train_data,
#      80         X=exogenous_data,
#      81         start_p=1, start_q=1,
#      82         test='adf',
#      83         max_p=3, max_q=3,
#      84         m=seasonal_period,
#      85         d=None,
#      86         seasonal=True,
#      87         start_P=0,
#      88         D=1,
#      89         trace=False,
#      90         error_action='ignore',
#      91         suppress_warnings=True,
#      92         stepwise=True,
#      93         n_jobs=-1,  # Use all available cores
#      94         maxiter = 10 # Limit iterations for faster debugging
#      95     )
#      96     return model
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\auto.py:701, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     669     # init the stepwise model wrapper
#     670     search = solvers._StepwiseFitWrapper(
#     671         y,
#     672         X=X,
#    (...)
#     698         **sarimax_kwargs,
#     699     )
# --> 701 sorted_res = search.solve()
#     702 return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\_auto_solvers.py:399, in _StepwiseFitWrapper.solve(self)
#     394     q -= 1
#     395     continue
#     397 if p < max_p and \
#     398         self.k < self.max_k and \
# --> 399         self._do_fit((p + 1, d, q), (P, D, Q, m)):
#     400     p += 1
#     401     continue
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\_auto_solvers.py:235, in _StepwiseFitWrapper._do_fit(self, order, seasonal_order, constant)
#     230 if (order, seasonal_order, constant) not in self.results_dict:
#     231
#     232     # increment the number of fits
#     233     self.k += 1
# --> 235     fit, fit_time, new_ic = self._fit_arima(
#     236         order=order,
#     237         seasonal_order=seasonal_order,
#     238         with_intercept=constant)
#     240     # use the orders as a key to be hashed for
#     241     # the dictionary (pointing to fit)
#     242     self.results_dict[(order, seasonal_order, constant)] = fit
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\_auto_solvers.py:508, in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     500 fit = ARIMA(order=order, seasonal_order=seasonal_order,
#     501             start_params=start_params, trend=trend, method=method,
#     502             maxiter=maxiter, suppress_warnings=suppress_warnings,
#     503             out_of_sample_size=out_of_sample_size, scoring=scoring,
#     504             scoring_args=scoring_args,
#     505             with_intercept=with_intercept, **kwargs)
#     507 try:
# --> 508     fit.fit(y, X=X, **fit_params)
#     510 # for non-stationarity errors or singular matrices, return None
#     511 except (LinAlgError, ValueError) as v:
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\arima.py:603, in ARIMA.fit(self, y, X, **fit_args)
#     600         X = safe_indexing(X, slice(0, n_exog - cv))
#     602 # Internal call
# --> 603 self._fit(y, X, **fit_args)
#     605 # now make a forecast if we're validating to compute the
#     606 # out-of-sample score
#     607 if cv_samples is not None:
#     608     # get the predictions (use self.predict, which calls forecast
#     609     # from statsmodels internally)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\arima.py:524, in ARIMA._fit(self, y, X, **fit_args)
#     522     with warnings.catch_warnings(record=False):
#     523         warnings.simplefilter('ignore')
# --> 524         fit, self.arima_res_ = _fit_wrapper()
#     525 else:
#     526     fit, self.arima_res_ = _fit_wrapper()
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\pmdarima\arima\arima.py:510, in ARIMA._fit.<locals>._fit_wrapper()
#     507 _maxiter = fit_args.pop("maxiter", _maxiter)
#     509 disp = fit_args.pop("disp", 0)
# --> 510 fitted = arima.fit(
#     511     start_params=start_params,
#     512     method=method,
#     513     maxiter=_maxiter,
#     514     disp=disp,
#     515     **fit_args,
#     516 )
#     518 return arima, fitted
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:705, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     703         flags['hessian_method'] = optim_hessian
#     704     fargs = (flags,)
# --> 705     mlefit = super().fit(start_params, method=method,
#     706                          fargs=fargs,
#     707                          maxiter=maxiter,
#     708                          full_output=full_output,
#     709                          disp=disp, callback=callback,
#     710                          skip_hessian=True, **kwargs)
#     712 # Just return the fitted parameters if requested
#     713 if return_params:
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\base\model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\base\optimizer.py:243, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     240     fit_funcs.update(extra_fit_funcs)
#     242 func = fit_funcs[method]
# --> 243 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     244                      disp=disp, maxiter=maxiter, callback=callback,
#     245                      retall=retall, full_output=full_output,
#     246                      hess=hessian)
#     248 optim_settings = {'optimizer': method, 'start_params': start_params,
#     249                   'maxiter': maxiter, 'full_output': full_output,
#     250                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     251                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     252 optim_settings.update(kwargs)
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\base\optimizer.py:660, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     657 elif approx_grad:
#     658     func = f
# --> 660 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     661                                  callback=callback, args=fargs,
#     662                                  bounds=bounds, disp=disp,
#     663                                  **extra_kwargs)
#     665 if full_output:
#     666     xopt, fopt, d = retvals
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:237, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     225 callback = _wrap_callback(callback)
#     226 opts = {'disp': disp,
#     227         'iprint': iprint,
#     228         'maxcor': m,
#    (...)
#     234         'callback': callback,
#     235         'maxls': maxls}
# --> 237 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     238                        **opts)
#     239 d = {'grad': res['jac'],
#     240      'task': res['message'],
#     241      'funcalls': res['nfev'],
#     242      'nit': res['nit'],
#     243      'warnflag': res['status']}
#     244 f = res['fun']
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\base\model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:934, in MLEModel.loglike(self, params, *args, **kwargs)
#     928 transformed, includes_fixed, complex_step, kwargs = _handle_args(
#     929     MLEModel._loglike_param_names, MLEModel._loglike_param_defaults,
#     930     *args, **kwargs)
#     932 params = self.handle_params(params, transformed=transformed,
#     933                             includes_fixed=includes_fixed)
# --> 934 self.update(params, transformed=True, includes_fixed=True,
#     935             complex_step=complex_step)
#     937 if complex_step:
#     938     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#
# File c:\Users\peera\.conda\envs\drought_lstm_base\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1656, in SARIMAX.update(self, params, transformed, includes_fixed, complex_step)
#    1649 # State intercept (Harvey) or additional observation intercept
#    1650 # (Hamilton)
#    1651 # SARIMA trend enters through the a time-varying state intercept,
#    1652 # associated with the first row of the stationary component of the
#    1653 # state vector (i.e. the first element of the state vector following
#    1654 # any differencing elements)
#    1655 if self._k_trend > 0:
# -> 1656     data = np.dot(self._trend_data, params_trend).astype(params.dtype)
#    1657     if not self.hamilton_representation:
#    1658         self.ssm['state_intercept', self._k_states_diff, :] = data
#
# KeyboardInterrupt:

# %%
# Ensure this path is correct from your notebook's location
config_file = "../config/sarima/config_SARIMA_PRE.yaml"

# Create an instance of the pipeline
sarima_pipeline = SarimaLocalPipeline(config_path=config_file)

# Execute the pipeline
all_sarima_metrics = sarima_pipeline.run_pipeline()

# %%
# Ensure this path is correct from your notebook's location
config_file = "../config/sarima/config_SARIMA_PET.yaml"

# Create an instance of the pipeline
sarima_pipeline = SarimaLocalPipeline(config_path=config_file)

# Execute the pipeline
all_sarima_metrics = sarima_pipeline.run_pipeline()
